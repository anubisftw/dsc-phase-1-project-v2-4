# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sqlite3

# %%
# %%bash
# sqlite3 zippedData/im.db
# .schema
# Out:
# CREATE TABLE IF NOT EXISTS "movie_basics" (
# "movie_id" TEXT,
#   "primary_title" TEXT,
#   "original_title" TEXT,
#   "start_year" INTEGER,
#   "runtime_minutes" REAL,
#   "genres" TEXT
# );
# CREATE TABLE IF NOT EXISTS "directors" (
# "movie_id" TEXT,
#   "person_id" TEXT
# );
# CREATE TABLE IF NOT EXISTS "known_for" (
# "person_id" TEXT,
#   "movie_id" TEXT
# );
# CREATE TABLE IF NOT EXISTS "movie_akas" (
# "movie_id" TEXT,
#   "ordering" INTEGER,
#   "title" TEXT,
#   "region" TEXT,
#   "language" TEXT,
#   "types" TEXT,
#   "attributes" TEXT,
#   "is_original_title" REAL
# );
# CREATE TABLE IF NOT EXISTS "movie_ratings" (
# "movie_id" TEXT,
#   "averagerating" REAL,
#   "numvotes" INTEGER
# );
# CREATE TABLE IF NOT EXISTS "persons" (
# "person_id" TEXT,
#   "primary_name" TEXT,
#   "birth_year" REAL,
#   "death_year" REAL,
#   "primary_profession" TEXT
# );
# CREATE TABLE IF NOT EXISTS "principals" (
# "movie_id" TEXT,
#   "ordering" INTEGER,
#   "person_id" TEXT,
# ...

# %%
movie_basics_query = '''
Select *
FROM movie_basics;'''

movie_ratings_query = '''
Select * 
FROM movie_ratings;'''


con = sqlite3.connect('zippedData/im.db')


movie_basics_df = pd.read_sql(movie_basics_query, con)
movie_ratings_df = pd.read_sql(movie_ratings_query, con)

# %%
movie_basics_df
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
movie_ratings_df
# Out:
#          movie_id  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
full_df
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146141  tt9916538                          Kuambil Lagi Hatiku
# 146142  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146143  tt9916706                              Dankyavar Danka
# 146144  tt9916730                                       6 Gunn
# 146145  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
df1 =  pd.read_csv('/Users/patrickpriestley/Downloads/Flatiron/dsc-phase-1-project-v2-4/zippedData/bom.movie_gross.csv')

# %%
full_df = movie_basics_df.merge(movie_ratings_df, how = 'left', on = 'movie_id').merge(df1, how ='left', left_on = 'primary_title', right_on = 'title')

# %%
df3 = full_df.dropna(subset=['domestic_gross', 'foreign_gross'], how='all')

# %%
df3["genres"].head(20)
# Out:
# 38            Action,Crime,Drama
# 48       Adventure,Drama,Romance
# 54        Adventure,Comedy,Drama
# 58            Action,Crime,Drama
# 60       Action,Adventure,Sci-Fi
# 61            Action,Crime,Drama
# 62                  Comedy,Drama
# 63                   Crime,Drama
# 67                 Comedy,Family
# 71    Adventure,Animation,Comedy
# 73       Action,Adventure,Sci-Fi
# 74                         Drama
# 80          Crime,Drama,Thriller
# 81        Action,Sci-Fi,Thriller
# 85          Drama,Mystery,Sci-Fi
# 86       Biography,Drama,History
# 92                        Comedy
# 95     Action,Adventure,Thriller
# 97       Horror,Mystery,Thriller
# 99           Action,Drama,Family
# Name: genres, dtype: object

# %%
topmvact = df3[df3['start_year'] > 2002].sort_values(by = 'domestic_gross', ascending = False).head(10)

# %%
fig,ax = plt.subplots()
 
# plotting columns
fig = sns.barplot(x=topmvact["domestic_gross"], y=topmvact["genres"], color='g')

ax.xaxis.offsetText.set_visible(False)
plt.xlabel("gross in billions")
plt.ylabel("movie genres")



plt.show()

# %%
sns.scatterplot(data = df3, x = "numvotes", y = "domestic_gross", hue ='genres')

plt.show()

# %%
sns.regplot(x=df3["numvotes"], y=df3["domestic_gross"])
# Out:
# <AxesSubplot:xlabel='numvotes', ylabel='domestic_gross'>

# %%
df3['super_hero'] = df3['genres'].str.contains('Action', 'Adventure',)
# Out:
# /var/folders/6d/1m4q0zbs33ngzwx1pxdmdjv80000gn/T/ipykernel_7079/1247743181.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['super_hero'] = df3['genres'].str.contains('Action', 'Adventure',)

# %% [markdown]
# df4

# %%
dfbudg = pd.read_csv('/Users/patrickpriestley/Downloads/tn.movie_budgets.csv')

# %%
dfbudg['production_budget'] = dfbudg['production_budget'].apply(lambda x: x.replace ('$',""))
dfbudg['production_budget'] = dfbudg['production_budget'].apply(lambda x: x.replace (',',""))
dfbudg['production_budget'] = dfbudg['production_budget'].apply(lambda x: int(x))

# %%
dfbudg['domestic_gross'] = dfbudg['domestic_gross'].apply(lambda x: x.replace ('$',""))
dfbudg['domestic_gross'] = dfbudg['domestic_gross'].apply(lambda x: x.replace (',',""))
dfbudg['domestic_gross'] = dfbudg['domestic_gross'].apply(lambda x: int(x))

# %%
dfbudg['worldwide_gross'] = dfbudg['worldwide_gross'].apply(lambda x: x.replace ('$',""))
dfbudg['worldwide_gross'] = dfbudg['worldwide_gross'].apply(lambda x: x.replace (',',""))
dfbudg['worldwide_gross'] = dfbudg['worldwide_gross'].apply(lambda x: int(x))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 dfbudg['worldwide_gross'] = dfbudg['worldwide_gross'].apply(lambda x: x.replace ('$',""))
#       2 dfbudg['worldwide_gross'] = dfbudg['worldwide_gross'].apply(lambda x: x.replace (',',""))
#       3 dfbudg['worldwide_gross'] = dfbudg['worldwide_gross'].apply(lambda x: int(x))
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:4433, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4323 def apply(
#    4324     self,
#    4325     func: AggFuncType,
#    (...)
#    4328     **kwargs,
#    4329 ) -> DataFrame | Series:
#    4330     """
#    4331     Invoke function on values of Series.
#    4332
#    (...)
#    4431     dtype: float64
#    4432     """
# -> 4433     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# ...

# %%
dfbudg
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross pdomestic_gross
# 0             425000000       760507625       2776345279     760,507,625
# ...

# %%
dfbudg['release_date'] = pd.to_datetime(dfbudg['release_date'])

# %%
dfbudg['year'] = dfbudg['release_date'].dt.year

# %%
dfbudg[dfbudg['year'] > 2017].sort_values(by = 'worldwide_gross', ascending = False).head(10)
# Out:
#      id release_date                           movie  production_budget  \
# 6     7   2018-04-27          Avengers: Infinity War          300000000
# 41   42   2018-02-16                   Black Panther          200000000
# 112  13   2018-06-22  Jurassic World: Fallen Kingdom          170000000
# 43   44   2018-06-15                   Incredibles 2          200000000
# 135  36   2018-12-21                         Aquaman          160000000
# 95   96   2019-03-08                  Captain Marvel          175000000
# 983  84   2018-11-02               Bohemian Rhapsody           55000000
# 302   3   2018-10-05                           Venom          116000000
# 91   92   2018-07-27   Mission: ImpossibleâFallout          178000000
# 314  15   2018-05-18                      Deadpool 2          110000000
#
#      domestic_gross  worldwide_gross pdomestic_gross  year
# 6         678815482       2048134200     678,815,482  2018
# ...

# %%
top10recentmovies= dfbudg[dfbudg['year'] > 2017].sort_values(by = 'worldwide_gross', ascending = False).head(10)

# %%
fig,ax = plt.subplots()
 
# plotting columns
fig = sns.barplot(x=top10recentmovies["worldwide_gross"], y=top10recentmovies["movie"], color='g')
fig = sns.barplot(x=top10recentmovies["domestic_gross"], y=top10recentmovies["movie"], color='lime')
ax.xaxis.offsetText.set_visible(False)
plt.xlabel("gross in billions")
plt.ylabel("movie")

plt.xticks(rotation=45)

plt.show()
# Out:
# /Users/patrickpriestley/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /Users/patrickpriestley/opt/anaconda3/lib/python3.9/site-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 148 (\x94) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
top10recentmovies
# Out:
#      id release_date                           movie  production_budget  \
# 6     7   2018-04-27          Avengers: Infinity War          300000000
# 41   42   2018-02-16                   Black Panther          200000000
# 112  13   2018-06-22  Jurassic World: Fallen Kingdom          170000000
# 43   44   2018-06-15                   Incredibles 2          200000000
# 135  36   2018-12-21                         Aquaman          160000000
# 95   96   2019-03-08                  Captain Marvel          175000000
# 983  84   2018-11-02               Bohemian Rhapsody           55000000
# 302   3   2018-10-05                           Venom          116000000
# 91   92   2018-07-27   Mission: ImpossibleâFallout          178000000
# 314  15   2018-05-18                      Deadpool 2          110000000
#
#      domestic_gross  worldwide_gross pdomestic_gross  year
# 6         678815482       2048134200     678,815,482  2018
# ...

# %%
sns.boxplot(dfbudg[dfbudg['worldwide_gross'] < 200000000]['worldwide_gross'])
# Out:
# /Users/patrickpriestley/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='worldwide_gross'>

# %%
sns.regplot(x=dfbudg["production_budget"], y=dfbudg["domestic_gross"])
# Out:
# <AxesSubplot:xlabel='production_budget', ylabel='domestic_gross'>

# %%
df5 = df3.merge(dfbudg, how = 'left')

# %%
df5.columns
# Out:
# Index(['movie_id', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'averagerating', 'numvotes', 'title',
#        'studio', 'domestic_gross', 'foreign_gross', 'year', 'super_hero', 'id',
#        'release_date', 'movie', 'production_budget', 'worldwide_gross',
#        'pdomestic_gross'],
#       dtype='object')

# %%
dfbudg.columns
# Out:
# Index(['id', 'release_date', 'movie', 'production_budget', 'domestic_gross',
#        'worldwide_gross', 'pdomestic_gross', 'year'],
#       dtype='object')

# %%
full_df.columns
# Out:
# Index(['movie_id', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'averagerating', 'numvotes', 'title',
#        'studio', 'domestic_gross', 'foreign_gross', 'year'],
#       dtype='object')

# %%
left_on= ['movie_id', 'year']

df8 = full_df.merge(dfbudg, how ='left', left_on = 'primary_title', right_on = 'movie')

# %%
df8
# Out:
#          movie_id                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146350  tt9916538                          Kuambil Lagi Hatiku
# 146351  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146352  tt9916706                              Dankyavar Danka
# 146353  tt9916730                                       6 Gunn
# 146354  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
df9 =  pd.read_csv("/Users/patrickpriestley/Downloads/data-14.tsv", sep="\t")

# %%
df9
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1922
# 1        tt0000002            5.8       259
# 2        tt0000003            6.5      1735
# 3        tt0000004            5.6       174
# 4        tt0000005            6.2      2548
# ...            ...            ...       ...
# 1247788  tt9916690            7.4         6
# 1247789  tt9916720            5.3       276
# 1247790  tt9916730            9.2         7
# 1247791  tt9916766            6.7        21
# 1247792  tt9916778            7.3        35
#
# [1247793 rows x 3 columns]

# %%
df10 =  pd.read_csv("/Users/patrickpriestley/Downloads/data-15.tsv", sep="\t")
# Out:
# /var/folders/6d/1m4q0zbs33ngzwx1pxdmdjv80000gn/T/ipykernel_7079/4145605759.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df10 =  pd.read_csv("/Users/patrickpriestley/Downloads/data-15.tsv", sep="\t")

# %%
df10
# Out:
#             tconst  titleType               primaryTitle  \
# 0        tt0000001      short                 Carmencita
# 1        tt0000002      short     Le clown et ses chiens
# 2        tt0000003      short             Pauvre Pierrot
# 3        tt0000004      short                Un bon bock
# 4        tt0000005      short           Blacksmith Scene
# ...            ...        ...                        ...
# 9374815  tt9916848  tvEpisode              Episode #3.17
# 9374816  tt9916850  tvEpisode              Episode #3.19
# 9374817  tt9916852  tvEpisode              Episode #3.20
# 9374818  tt9916856      short                   The Wind
# 9374819  tt9916880  tvEpisode  Horrid Henry Knows It All
#
#                      originalTitle isAdult startYear endYear runtimeMinutes  \
# 0                       Carmencita       0      1894      \N              1
# 1           Le clown et ses chiens       0      1892      \N              5
# ...

# %%
df11 =  pd.read_csv("/Users/patrickpriestley/Downloads/data-16.tsv", sep="\t")

# %%
df11
# Out:
#              tconst  ordering      nconst         category  \
# 0         tt0000001         1   nm1588970             self
# 1         tt0000001         2   nm0005690         director
# 2         tt0000001         3   nm0374658  cinematographer
# 3         tt0000002         1   nm0721526         director
# 4         tt0000002         2   nm1335271         composer
# ...             ...       ...         ...              ...
# 53067449  tt9916880         4  nm10535738          actress
# 53067450  tt9916880         5   nm0996406         director
# 53067451  tt9916880         6   nm1482639           writer
# 53067452  tt9916880         7   nm2586970           writer
# 53067453  tt9916880         8   nm1594058         producer
#
#                               job        characters
# 0                              \N          ["Self"]
# 1                              \N                \N
# 2         director of photography                \N
# ...

# %%
df12 =  pd.read_csv("/Users/patrickpriestley/Downloads/data-17.tsv", sep="\t")
# Out:
# /var/folders/6d/1m4q0zbs33ngzwx1pxdmdjv80000gn/T/ipykernel_7079/3958717647.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df12 =  pd.read_csv("/Users/patrickpriestley/Downloads/data-17.tsv", sep="\t")

# %%
df12
# Out:
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA       \N
# 1         tt0000001         2                 Carmencita     DE       \N
# 2         tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3         tt0000001         4                 Καρμενσίτα     GR       \N
# 4         tt0000001         5                 Карменсита     RU       \N
# ...             ...       ...                        ...    ...      ...
# 33840585  tt9916852         5             Episódio #3.20     PT       pt
# 33840586  tt9916852         6             Episodio #3.20     IT       it
# 33840587  tt9916852         7               एपिसोड #3.20     IN       hi
# 33840588  tt9916856         1                   The Wind     DE       \N
# 33840589  tt9916856         2                   The Wind     \N       \N
#
#                 types     attributes isOriginalTitle
# ...

# %%
df13 =  pd.read_csv("/Users/patrickpriestley/Downloads/data-18.tsv", sep="\t")

# %%
df13
# Out:
#              nconst         primaryName birthYear deathYear  \
# 0         nm0000001        Fred Astaire      1899      1987
# 1         nm0000002       Lauren Bacall      1924      2014
# 2         nm0000003     Brigitte Bardot      1934        \N
# 3         nm0000004        John Belushi      1949      1982
# 4         nm0000005      Ingmar Bergman      1918      2007
# ...             ...                 ...       ...       ...
# 12080171  nm9993714   Romeo del Rosario        \N        \N
# 12080172  nm9993716       Essias Loberg        \N        \N
# 12080173  nm9993717  Harikrishnan Rajan        \N        \N
# 12080174  nm9993718         Aayush Nair        \N        \N
# 12080175  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# ...

# %%
df14 =  pd.read_csv("/Users/patrickpriestley/Downloads/data-19.tsv", sep="\t")

# %%
df14
# Out:
#             tconst            directors                        writers
# 0        tt0000001            nm0005690                             \N
# 1        tt0000002            nm0721526                             \N
# 2        tt0000003            nm0721526                             \N
# 3        tt0000004            nm0721526                             \N
# 4        tt0000005            nm0005690                             \N
# ...            ...                  ...                            ...
# 9374815  tt9916848  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 9374816  tt9916850  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 9374817  tt9916852  nm5519454,nm5519375  nm6182221,nm1628284,nm2921377
# 9374818  tt9916856           nm10538645                      nm6951431
# 9374819  tt9916880            nm0996406            nm1482639,nm2586970
#
# [9374820 rows x 3 columns]

# %%
dfmr = df13.merge(df10, how = 'right', on = 'tconst')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [210], in <cell line: 1>()
# ----> 1 dfmr = df13.merge(df10, how = 'right', on = 'tconst')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# -> 9345     return merge(
#    9346         self,
#    9347         right,
#    9348         how=how,
#    9349         on=on,
#    9350         left_on=left_on,
#    9351         right_on=right_on,
#    9352         left_index=left_index,
#    9353         right_index=right_index,
# ...
