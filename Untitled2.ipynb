# %%
dfmvinfo = pd.read_csv('/Users/patrickpriestley/Downloads/zippedData/tmdb.movies.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 dfmvinfo = pd.read_csv('/Users/patrickpriestley/Downloads/zippedData/tmdb.movies.csv')
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dfmvinfo = pd.read_csv('zippedData/tmdb.movies.csv')

# %%
dfmvinfo
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %%
import sqlite3 
conn = sqlite3.connect('im.db')

# %%
import csv

# %%
dfmvinfo = pd.read_csv('zippedData/tmdb.movies.csv')

# %%
dfmvinfo
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %%
dfbom = pd.read_csv("zippedData/bom.movie_gross.csv")

# %%
newdf = dfmvinfo.merge(dfbom, how = 'left', left_on = 'original_title', right_on = 'title' )

# %%
newdf
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                             title_x  vote_average  vote_count  \
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
#                         title_y studio  domestic_gross foreign_gross    year
# 0                           NaN    NaN             NaN           NaN     NaN
# 1      How to Train Your Dragon   P/DW     217600000.0     277300000  2010.0
# 2                    Iron Man 2   Par.     312400000.0     311500000  2010.0
# 3                           NaN    NaN             NaN           NaN     NaN
# 4                     Inception     WB     292600000.0     535700000  2010.0
# ...                         ...    ...             ...           ...     ...
# 26512                       NaN    NaN             NaN           NaN     NaN
# 26513                       NaN    NaN             NaN           NaN     NaN
# 26514                       NaN    NaN             NaN           NaN     NaN
# 26515                       NaN    NaN             NaN           NaN     NaN
# 26516                       NaN    NaN             NaN           NaN     NaN
#
# [26517 rows x 15 columns]

# %%
dfbudg = pd.read_csv('/Users/patrickpriestley/Downloads/tn.movie_budgets.csv')

# %%
dfbudg['production_budget'] = dfbudg['production_budget'].apply(lambda x: x.replace ('$',""))
dfbudg['production_budget'] = dfbudg['production_budget'].apply(lambda x: x.replace (',',""))
dfbudg['production_budget'] = dfbudg['production_budget'].apply(lambda x: int(x))

# %%
dfbudg['domestic_gross'] = dfbudg['domestic_gross'].apply(lambda x: x.replace ('$',""))
dfbudg['domestic_gross'] = dfbudg['domestic_gross'].apply(lambda x: x.replace (',',""))
dfbudg['domestic_gross'] = dfbudg['domestic_gross'].apply(lambda x: int(x))

# %%
dfbudg['worldwide_gross'] = dfbudg['worldwide_gross'].apply(lambda x: x.replace ('$',""))
dfbudg['worldwide_gross'] = dfbudg['worldwide_gross'].apply(lambda x: x.replace (',',""))
dfbudg['worldwide_gross'] = dfbudg['worldwide_gross'].apply(lambda x: int(x))

# %%
dfbudg
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross
# 0             425000000       760507625       2776345279
# 1             410600000       241063875       1045663875
# 2             350000000        42762350        149762350
# 3             330600000       459005868       1403013963
# 4             317000000       620181382       1316721747
# ...                 ...             ...              ...
# 5777               7000               0                0
# 5778               6000           48482           240495
# 5779               5000            1338             1338
# 5780               1400               0                0
# 5781               1100          181041           181041
#
# [5782 rows x 6 columns]

# %%
newdf.merge(dfbudg, how = 'left', left_on = 'original_title' , right_on = 'movie')
# Out:
#        Unnamed: 0            genre_ids    id_x original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26592       26512             [27, 18]  488143                en
# 26593       26513             [18, 53]  485975                en
# 26594       26514         [14, 28, 12]  381231                en
# 26595       26515      [10751, 12, 28]  366854                en
# 26596       26516             [53, 27]  309885                en
#
#                                      original_title  popularity  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533
# 1                          How to Train Your Dragon      28.734
# 2                                        Iron Man 2      28.515
# 3                                         Toy Story      28.005
# 4                                         Inception      27.920
# ...                                             ...         ...
# 26592                         Laboratory Conditions       0.600
# 26593                               _EXHIBIT_84xxx_       0.600
# 26594                                  The Last One       0.600
# 26595                                  Trailer Made       0.600
# 26596                                    The Church       0.600
#
#       release_date_x                                       title_x  \
# 0         2010-11-19  Harry Potter and the Deathly Hallows: Part 1
# 1         2010-03-26                      How to Train Your Dragon
# 2         2010-05-07                                    Iron Man 2
# 3         1995-11-22                                     Toy Story
# 4         2010-07-16                                     Inception
# ...              ...                                           ...
# 26592     2018-10-13                         Laboratory Conditions
# 26593     2018-05-01                               _EXHIBIT_84xxx_
# 26594     2018-10-01                                  The Last One
# 26595     2018-06-22                                  Trailer Made
# 26596     2018-10-05                                    The Church
#
#        vote_average  vote_count  ... studio domestic_gross_x  foreign_gross  \
# 0               7.7       10788  ...    NaN              NaN            NaN
# 1               7.7        7610  ...   P/DW      217600000.0      277300000
# 2               6.8       12368  ...   Par.      312400000.0      311500000
# 3               7.9       10174  ...    NaN              NaN            NaN
# 4               8.3       22186  ...     WB      292600000.0      535700000
# ...             ...         ...  ...    ...              ...            ...
# 26592           0.0           1  ...    NaN              NaN            NaN
# 26593           0.0           1  ...    NaN              NaN            NaN
# 26594           0.0           1  ...    NaN              NaN            NaN
# 26595           0.0           1  ...    NaN              NaN            NaN
# 26596           0.0           1  ...    NaN              NaN            NaN
#
#          year  id_y  release_date_y                     movie  \
# 0         NaN   NaN             NaN                       NaN
# 1      2010.0  30.0    Mar 26, 2010  How to Train Your Dragon
# 2      2010.0  15.0     May 7, 2010                Iron Man 2
# 3         NaN  37.0    Nov 22, 1995                 Toy Story
# 4      2010.0  38.0    Jul 16, 2010                 Inception
# ...       ...   ...             ...                       ...
# 26592     NaN   NaN             NaN                       NaN
# 26593     NaN   NaN             NaN                       NaN
# 26594     NaN   NaN             NaN                       NaN
# 26595     NaN   NaN             NaN                       NaN
# 26596     NaN   NaN             NaN                       NaN
#
#       production_budget  domestic_gross_y  worldwide_gross
# 0                   NaN               NaN              NaN
# 1           165000000.0       217581232.0      494870992.0
# 2           170000000.0       312433331.0      621156389.0
# 3            30000000.0       191796233.0      364545516.0
# 4           160000000.0       292576195.0      835524642.0
# ...                 ...               ...              ...
# 26592               NaN               NaN              NaN
# 26593               NaN               NaN              NaN
# 26594               NaN               NaN              NaN
# 26595               NaN               NaN              NaN
# 26596               NaN               NaN              NaN
#
# [26597 rows x 21 columns]

# %%
dfbudg
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross
# 0             425000000       760507625       2776345279
# 1             410600000       241063875       1045663875
# 2             350000000        42762350        149762350
# 3             330600000       459005868       1403013963
# 4             317000000       620181382       1316721747
# ...                 ...             ...              ...
# 5777               7000               0                0
# 5778               6000           48482           240495
# 5779               5000            1338             1338
# 5780               1400               0                0
# 5781               1100          181041           181041
#
# [5782 rows x 6 columns]

# %%
newdf2 = newdf.merge(dfbudg, how = 'left', right_on = 'movie', left_on = 'title_x' )

# %%
newdf2
# Out:
#        Unnamed: 0            genre_ids    id_x original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26601       26512             [27, 18]  488143                en
# 26602       26513             [18, 53]  485975                en
# 26603       26514         [14, 28, 12]  381231                en
# 26604       26515      [10751, 12, 28]  366854                en
# 26605       26516             [53, 27]  309885                en
#
#                                      original_title  popularity  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533
# 1                          How to Train Your Dragon      28.734
# 2                                        Iron Man 2      28.515
# 3                                         Toy Story      28.005
# 4                                         Inception      27.920
# ...                                             ...         ...
# 26601                         Laboratory Conditions       0.600
# 26602                               _EXHIBIT_84xxx_       0.600
# 26603                                  The Last One       0.600
# 26604                                  Trailer Made       0.600
# 26605                                    The Church       0.600
#
#       release_date_x                                       title_x  \
# 0         2010-11-19  Harry Potter and the Deathly Hallows: Part 1
# 1         2010-03-26                      How to Train Your Dragon
# 2         2010-05-07                                    Iron Man 2
# 3         1995-11-22                                     Toy Story
# 4         2010-07-16                                     Inception
# ...              ...                                           ...
# 26601     2018-10-13                         Laboratory Conditions
# 26602     2018-05-01                               _EXHIBIT_84xxx_
# 26603     2018-10-01                                  The Last One
# 26604     2018-06-22                                  Trailer Made
# 26605     2018-10-05                                    The Church
#
#        vote_average  vote_count  ... studio domestic_gross_x  foreign_gross  \
# 0               7.7       10788  ...    NaN              NaN            NaN
# 1               7.7        7610  ...   P/DW      217600000.0      277300000
# 2               6.8       12368  ...   Par.      312400000.0      311500000
# 3               7.9       10174  ...    NaN              NaN            NaN
# 4               8.3       22186  ...     WB      292600000.0      535700000
# ...             ...         ...  ...    ...              ...            ...
# 26601           0.0           1  ...    NaN              NaN            NaN
# 26602           0.0           1  ...    NaN              NaN            NaN
# 26603           0.0           1  ...    NaN              NaN            NaN
# 26604           0.0           1  ...    NaN              NaN            NaN
# 26605           0.0           1  ...    NaN              NaN            NaN
#
#          year  id_y  release_date_y                     movie  \
# 0         NaN   NaN             NaN                       NaN
# 1      2010.0  30.0    Mar 26, 2010  How to Train Your Dragon
# 2      2010.0  15.0     May 7, 2010                Iron Man 2
# 3         NaN  37.0    Nov 22, 1995                 Toy Story
# 4      2010.0  38.0    Jul 16, 2010                 Inception
# ...       ...   ...             ...                       ...
# 26601     NaN   NaN             NaN                       NaN
# 26602     NaN   NaN             NaN                       NaN
# 26603     NaN   NaN             NaN                       NaN
# 26604     NaN   NaN             NaN                       NaN
# 26605     NaN   NaN             NaN                       NaN
#
#       production_budget  domestic_gross_y  worldwide_gross
# 0                   NaN               NaN              NaN
# 1           165000000.0       217581232.0      494870992.0
# 2           170000000.0       312433331.0      621156389.0
# 3            30000000.0       191796233.0      364545516.0
# 4           160000000.0       292576195.0      835524642.0
# ...                 ...               ...              ...
# 26601               NaN               NaN              NaN
# 26602               NaN               NaN              NaN
# 26603               NaN               NaN              NaN
# 26604               NaN               NaN              NaN
# 26605               NaN               NaN              NaN
#
# [26606 rows x 21 columns]

# %%
sns.regplot(x=cashvote["production_budget"], y=cashvote["worldwide_gross"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [62], in <cell line: 1>()
# ----> 1 sns.regplot(x=cashvote["production_budget"], y=cashvote["worldwide_gross"])
#
# NameError: name 'cashvote' is not defined
